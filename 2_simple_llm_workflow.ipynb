# %%
from langgraph.graph import StateGraph, START , END
from dotenv import load_dotenv
from typing import TypedDict
from langchain_openai import ChatOpenAI
from langchain_nvidia_ai_endpoints import ChatNVIDIA

# %%
pip install langchain_openai
# Out:
# Requirement already satisfied: langchain_openai in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (1.3.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langchain_openai) (1.4.7)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langchain_openai) (2.43.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langchain_openai) (0.13.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain_openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain_openai) (0.0.17)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain_openai) (0.8.16)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain_openai) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain_openai) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain_openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain_openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain_openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain_openai) (0.16.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain_openai) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain_openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain_openai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain_openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain_openai) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain_openai) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain_openai) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain_openai) (0.25.0)
# Requirement already satisfied: anyio in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain_openai) (4.14.0)
# Requirement already satisfied: certifi in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain_openai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain_openai) (1.0.9)
# Requirement already satisfied: idna in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain_openai) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain_openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (0.15.0)
# Requirement already satisfied: sniffio in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain_openai) (4.68.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.7->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.7->langchain_openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.7->langchain_openai) (0.4.2)
# Requirement already satisfied: regex in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2026.5.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain_openai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain_openai) (2.7.0)
# Requirement already satisfied: colorama in c:\users\priyanshu\desktop\langgrapgh\myenv\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain_openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
load_dotenv()
# Out:
# True

# %%
import os
model = ChatNVIDIA(
    model="moonshotai/kimi-k2.6",
    api_key=os.getenv("KIMI_API"),
    temperature=1,
    top_p=1,
    max_completion_tokens=16384,
)
# Out:
# c:\Users\PRIYANSHU\Desktop\LANGGRAPGH\myenv\Lib\site-packages\langchain_nvidia_ai_endpoints\_common.py:250: UserWarning: Found moonshotai/kimi-k2.6 in available_models, but type is unknown and inference may fail.
#   warnings.warn(

# %%
# create a state

class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following question {question}'

    # ask that question to the LLM
    answer = model.invoke(prompt).content

    # update the answer in the state
    state['answer'] = answer

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa', llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile
workflow = graph.compile()

# %%
# execute

intial_state = {'question': 'How far is moon from the earth?'}

final_state = workflow.invoke(intial_state)

print(final_state['answer'])
# Out:
#  The average distance from the **Moon to Earth** is about **384,400 kilometers (238,855 miles)**.
#
# However, because the Moon's orbit is **elliptical** (oval-shaped), this distance varies:
#
# | Point in Orbit | Distance from Earth |
# |----------------|---------------------|
# | **Perigee** (closest) | ~356,500 km (~221,500 mi) |
# | **Apogee** (farthest) | ~406,700 km (~252,700 mi) |
#
# So the Moon can be closer or farther depending on where it is in its orbit.
